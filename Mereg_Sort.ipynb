# %%
#@title
def mergesort(any_list):
    if len(any_list) == 1:
        return lst
    if len(any_list)== 2:
        return sorted(any_list)
    else:
        len(any_list) > 2
        third = len(arr)//3
        
        left = mergesort(any_list[:third])
        middle = mergesort(any_list[third:(2*third)])
        right = mergesort(any_list[(2*third):])
    return left, middle, right
        
def merge(left, middle, right):   
    merged = []
    i,j,k = 0,0,0
    
    while i < len(first_third) and j < len(second_third) and k < len(last_third):
        if first_third[i] < second_third[j] < last_third[k]:
            merged.append(first_third[i])
            i += 1
        elif second_third[j] < first_third[i] < last_third[k]: 
            merged.append(second_third[j])
            j += 1
        elif merged.append(last_third[k]):
            k += 1
    
    merged += left[i:]
    merged += middle[j:]
    merged += right[k:]
    return merged

any_list = [int (x) for x in input("Enter a list of numbers you would like sorted: ")]

mergesort(any_list)

print(mergesort(any_list))

# %%
def merge(all_lst):
    sorted_lst = []
    while all_lst:
        min_value,index = all_lst[0][0],0
        for lst in all_lst:
            if lst[0]<min_value:
                min_value = lst[0]
                index = all_lst.index(lst)
        sorted_lst.append(min_value)
        all_lst[index].pop(0)
        if not all_lst[index]:
            all_lst.remove(all_lst[index])     
    return sorted_lst
  
def merge_sort(lst, k):
    if len(lst) == 1: # simpler base case
        return lst

    j = ceil(len(lst)/k) # no need to check for k < len(lst) (ceil handles it)

    #split and recursively sort in one step
    lst = [merge_sort(lst[i:i+j], k) for i in range(0, len(lst), j)]

    return merge(lst)

lst = 9, 67, 0, 35, 1, 26, 17
k = input("Enter the value of k: ")
print (merge(lst))

# %%
    if len(any_list) < 2:
        return (any_list)
      
    else: 
        len(any_list) > 1
        third_1 = len(any_list)*(1//3)
        
        first_third = any_list[:third_1]
        second_third = any_list[third_1:2*third_1]
        last_third = any_list[2*third_1:]
        
        sorted(first_third)
        sorted(second_third)
        sorted(last_third)

# %%
def mergesort(lst):
    if len(arr) == 1:
        return lst
    if len(arr)== 2:
        return sorted(arr)
    else:
        s = len(arr)//3
        left = mergesort(arr[:s])
        middle = mergesort(arr[s:(2*s)])
        right = mergesort(arr[(2*s):])
        return merge(left,middle, right)
 

def merge(left,middle,right):
    
    t = len(left)+len(middle) + len(right)
    result = []
    
    i,j,k = 0,0,0
    
    left.append(float("inf"))
    middle.append(float("inf"))
    right.append(float("inf"))
    
    while i < len(left) and j < len(middle) and k < len(right)and t-1>=len(result):
        
        if (left[i] <= middle[j] and left[i] <= right[k]):
            result.append(left[i])
            i+=1
        elif (middle[j] <= left[i]  and middle[j] <= right[k]):
            result.append(middle[j])
            j+=1
        elif right[k]:
            result.append(right[k])
            k+=1
    return result

arr = input("Enter a list of numbers you would like sorted: ")
mergesort(arr)
print (mergesort(arr))
